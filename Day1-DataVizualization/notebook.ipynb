# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_style("darkgrid")

# %% [markdown]
# <h1 style="color:skyblue" >Part 1: Listing basic visualization methods</h1>

# %%
#Loading the dataset
data = sns.load_dataset("iris")

print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <h3>1.Scatter Plot</h3>
# <h5>Scatter plots are used to find the relation between bi-variate data</h5>

# %%
plt.figure(figsize=(15,7))

plt.title("Scatter of sepal_length")
plt.xlabel("sepal_length")
plt.ylabel("Range")


#using seaborn
sns.scatterplot( x=data.sepal_length, y = sorted(data.sepal_length))  

#Using matplotlib
#plt.scatter(x=data.sepal_length, y = sorted(data.sepal_length))
# Out:
# <AxesSubplot:title={'center':'Scatter of sepal_length'}, xlabel='sepal_length', ylabel='Range'>

# %% [markdown]
# <h2>1.5 Hexbin Plot</h2>
# <h5>Hexbins improve the visualization of scatterplots by color encoding the points based on frequency</h5>

# %%
plt.figure(figsize=(15,7))

plt.title("Scatter of sepal_length")
plt.xlabel("sepal_length")
plt.ylabel("Range")

plt.hexbin(x=data.sepal_length, y = sorted(data.sepal_length))

# %% [markdown]
# <h3>2.Histogram</h3>
# <h5>Histograms help in understanding the distrubution of data about any one particular dimension</h5>

# %%
plt.figure(figsize=(15,7))

plt.title("Distribution of sepal_length")
plt.xlabel("sepal_lenth")
plt.ylabel("frequency")

#using seaborn
sns.histplot(data = data, x = "sepal_length", bins = 30, kde = True)  

#Using matplotlib
#plt.hist(data.sepal_length, bins = 30)
# Out:
# <AxesSubplot:title={'center':'Distribution of sepal_length'}, xlabel='sepal_lenth', ylabel='frequency'>

# %% [markdown]
# <h3>3. Bar Graphs</h3>
# <h5>Bar graphs help visualize the frequency or an estimate of central tendency of different groups in a single dimenion of data.</h5>

# %%
plt.figure(figsize=(15,7))


#Using matplotlib
#plt.bar(data.species, data.sepal_length) #Using matplotlib

#using seaborn
sns.barplot(data = data ,x= "species", y = "sepal_length") 


print(data.species.value_counts())
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# <h3>4. Pie Chart</h3>
# <h5> Pie charts help visualize proportions of each category in categorical data</h5>

# %%
plt.figure(figsize=(10,5))

#Using matplotlib
plt.pie(data.species.value_counts().values, labels = data.species.value_counts().keys()   ,explode= [0.2, 0.05 , 0.05]) 

#seaborn has no function to make piecharts
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0735270b50>,
# ...
#  [Text(0.6499999648639682, 1.125833045205567, 'versicolor'),
#   Text(-1.1499999999999952, -1.0767077042522502e-07, 'setosa'),
#   Text(0.575000155409364, -0.9959291246264501, 'virginica')])

# %% [markdown]
# <h2>5.Box plot</h2>
# <h5> Box plots help understand the distribution of data using the five-number summary method that displays the values - Minimum, 1st Quartile, Median, 3rd Quartile, Maximum. </h5>

# %%
plt.figure(figsize=(15, 7))

plt.title("Box plot of numerical dimensions of the iris dataset")
plt.ylabel("Distribution")

#using matplotlib
#plt.boxplot([data.sepal_length, data.sepal_width, data.petal_length, data.petal_width], labels=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']) 

#using seaborn
sns.boxplot(data = data)
# Out:
# <AxesSubplot:title={'center':'Box plot of numerical dimensions of the iris dataset'}, ylabel='Distribution'>

# %% [markdown]
# <h2>5. Violin plot</h2>
# <h5> Violin plots are box plots with an additional rotated Kernel Density Estimates</h5>

# %%
plt.figure(figsize=(15, 7))

plt.title("Violin plot of numerical dimensions of the iris dataset")
plt.ylabel("Distribution")

#using matplotlib
#plt.violinplot([data.sepal_length, data.sepal_width, data.petal_length, data.petal_width])

#using seaborn
sns.violinplot(data = data)
# Out:
# <AxesSubplot:title={'center':'Violin plot of numerical dimensions of the iris dataset'}, ylabel='Distribution'>

# %% [markdown]
# <h2> 6. Heatmap</h2>
# <h5>Heatmaps are a type of matrix plots that allow you to plot matrix data as color-encoded matrices. They are mostly used to find multi-collinearity in a dataset.</h5>

# %%
plt.figure(figsize=(15,7))

plt.title("Heatmap representing correlations between numerical entities in Iris dataset")

print("Correlation matrix :\n", data.corr())

#using seaborn
sns.heatmap(data.corr(), cmap = "crest", annot = True)

#matplotlib has no functions to make heatmaps
# Out:
# Correlation matrix :
#                sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# <AxesSubplot:title={'center':'Heatmap representing correlations between numerical entities in Iris dataset'}>

# %% [markdown]
# <h2>7.Pair plot</h2>
# <h5>Plot pairwise relationships in a dataset.</h5>

# %%
sns.pairplot(data = data, kind = "scatter", diag_kind="kde", hue = "species", height= 3)
plt.title("Pair plot")
# Out:
# Text(0.5, 1.0, 'Pair plot')

# %% [markdown]
# <h2> 8. Joint Plot</h2>
# <h5> A combination of Histograms and scatterplots. Jointplot is used to represent the distribution of one variable to match up with the distribution of another variable.</h5>

# %%
sns.jointplot(data.sepal_length, data.sepal_width, height= 10)
# Out:
# /home/racgreen1/anaconda3/envs/ML/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
